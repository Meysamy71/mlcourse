# %% [markdown]
# # Visualizing the Titanic Disaster

# %% [markdown]
# ### Introduction:
#
# This exercise is based on the titanic Disaster dataset avaiable at [Kaggle](https://www.kaggle.com/c/titanic).
# To know more about the variables check [here](https://www.kaggle.com/c/titanic/data)
#
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ### Step 2. Import the dataset

# %%
pd.read_csv('titanic.csv')
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Step 3. Assign it to a variable titanic

# %%
titanic = pd.read_csv('titanic.csv')
titanic
# Out:
#      PassengerId  Survived  Pclass  \
# 0              1         0       3
# 1              2         1       1
# 2              3         1       3
# 3              4         1       1
# 4              5         0       3
# ..           ...       ...     ...
# 886          887         0       2
# 887          888         1       1
# 888          889         0       3
# 889          890         1       1
# 890          891         0       3
#
#                                                   Name     Sex   Age  SibSp  \
# 0                              Braund, Mr. Owen Harris    male  22.0      1
# 1    Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0      1
# 2                               Heikkinen, Miss. Laina  female  26.0      0
# 3         Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0      1
# 4                             Allen, Mr. William Henry    male  35.0      0
# ..                                                 ...     ...   ...    ...
# ...

# %% [markdown]
# ### Step 4. Set PassengerId as the index

# %%
titanic = titanic.set_index('PassengerId')
titanic
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %% [markdown]
# ### Step 5. Create a pie chart presenting the male/female proportion

# %%
GenderChart = titanic.Sex.value_counts(normalize=True) * 100
Mylabel = ['Male', 'Female']
plt.pie(GenderChart, labels=Mylabel, autopct='%1.1f%%', colors=['DodgerBlue', 'DeepPink'])
plt.title('Proportion (%) of male and female')
plt.legend(title='Gender')
plt.show()

# %% [markdown]
# ### Step 6. Create a scatterplot with the Fare payed and the Age, differ the plot color by gender

# %%
FarePayed = titanic
FarePayed.Age.fillna(100, inplace=True)

plt.scatter(FarePayed[FarePayed['Sex'] == 'male'].Age,FarePayed[FarePayed['Sex'] == 'male'].Fare,label='Male')
plt.scatter(FarePayed[FarePayed['Sex'] == 'female'].Age,FarePayed[FarePayed['Sex'] == 'female'].Fare,label='Female')

plt.title("Fare payed and the Age")
plt.xlabel("Age in years")
plt.ylabel("Passenger fare")
plt.legend()
plt.show()
# Out:
# C:\Users\MeysaM\AppData\Local\Temp\ipykernel_16968\1846566964.py:2: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   FarePayed.Age.fillna(100, inplace=True)

# %% [markdown]
# ### Step 7. How many people survived?

# %%
titanic.Survived.value_counts().iloc[1]
# Out:
# 342

# %% [markdown]
# ### Step 8. Create a histogram with the Fare payed

# %%
sns.set(style="white")
colors = sns.color_palette("viridis", n_colors=1)

plt.figure(figsize=(10, 6))
sns.histplot(titanic['Fare'], kde=True, color=colors[0])

sns.despine(left=True, bottom=True)

plt.title("Fare Histogram", fontsize=18, color='darkgreen')
plt.xlabel("Fare", fontsize=14, color='darkgreen')
plt.ylabel("Density", fontsize=14, color='darkgreen')

plt.xticks(color='orange')
plt.yticks(color='orange')

plt.show()

# %% [markdown]
# ### BONUS: Create your own question and answer it.
